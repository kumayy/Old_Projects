# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


# %matplotlib inline

# %% [markdown]
# # Example 1
#
# ## $f(x) = x^2 +x + 1$

# %%
def f(x):
    return x**2 + x + 1

# %%
# Make data
x_1 = np.linspace(start= -3, stop= 3, num= 500)

# %%
# Plot
plt.xlim([-3,3])
plt.ylim([0,8])
plt.xlabel("x", fontsize = 14)
plt.ylabel("f (x)", fontsize = 14)
plt.plot(x_1, f(x_1))

plt.show()

# %% [markdown]
# ## Slope and Derivatives

# %%
def df(x):
    return 2*x + 1

# %%
# Plot of Derivative

plt.figure(figsize = [15,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 2, 1)
plt.title("Cost Function", fontsize = 16)

plt.xlim([-3,3])
plt.ylim([0,8])
plt.xlabel("x", fontsize = 14)
plt.ylabel("f (x)", fontsize = 14)

plt.plot(x_1, f(x_1), color = "skyblue", linewidth = 4)

# Chart 2: DERİVATİVE

plt.subplot(1, 2, 2)
plt.title("Slope of the Cost Function", fontsize = 16)

plt.xlim([-2,3])
plt.ylim([-3,6])
plt.grid()
plt.xlabel("x", fontsize = 14)
plt.ylabel("df (x)", fontsize = 14)

plt.plot(x_1, df(x_1), color = "red", linewidth= 5)

plt.show()

# %% [markdown]
# ## Python Loops & Gradient Descent

# %%
# For loop
for n in range(5):
    print("hello world", n+1)
print("End of loop")
# Out:
# hello world 1
# hello world 2
# hello world 3
# hello world 4
# hello world 5
# End of loop

# %%
# While loop
counter = 10
while counter > 0:
    print("Counting ...", counter)
    counter -= 1
print(" Ready or not, HERE I COME!!...")
# Out:
# Counting ... 10
# Counting ... 9
# Counting ... 8
# Counting ... 7
# Counting ... 6
# Counting ... 5
# Counting ... 4
# Counting ... 3
# Counting ... 2
# Counting ... 1
#  Ready or not, HERE I COME!!...

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplyer = 0.1
precision = 0.001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(1000):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplyer * gradient

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))


    if step_size < precision:
        print(f"Loop ran {n} times")
        break

print(f"Local minimum occurs at: {new_x}")
print(f"Slope, df(x), at this point is: {df(new_x)}")
print("f(x) value, cost at this point, is:", f(new_x))
# Out:
# Loop ran 30 times
# Local minimum occurs at: -0.4965337678900009
# Slope, df(x), at this point is: 0.006932464219998158
# f(x) value, cost at this point, is: 0.7500120147650404

# %%
# Superimpose the gradient descent calculationson Plot

plt.figure(figsize = [18,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 3, 1)
plt.title("Cost Function", fontsize = 16)

plt.xlim([-3,3])
plt.ylim([0,8])
plt.xlabel("x", fontsize = 14)
plt.ylabel("f (x)", fontsize = 14)

plt.plot(x_1, f(x_1), color = "skyblue", linewidth = 4, alpha = 0.75)

values = np.array(x_list)
plt.scatter(x_list, f(values), color = "red", s = 100, alpha = 0.8)

# Chart 2: DERİVATİVE

plt.subplot(1, 3, 2)
plt.title("Slope of the Cost Function", fontsize = 16)

plt.xlim([-2,3])
plt.ylim([-3,6])
plt.grid()
plt.xlabel("x", fontsize = 14)
plt.ylabel("df (x)", fontsize = 14)

plt.plot(x_1, df(x_1), color = "red", linewidth= 5, alpha = 0.8)
plt.scatter(x_list, slope_list, color = "blue", alpha = 0.8, s= 100)

# Chart 3: Derivative (Close up)

plt.subplot(1,3,3)
plt.title("Gradient Descent (close up)", fontsize = 16)
plt.xlabel("x", fontsize = 14)
plt.grid()
plt.xlim([-0.55,-0.3])
plt.ylim([-0.2,0.5])

plt.plot(x_1, df(x_1), color = "red", linewidth= 5, alpha = 0.8)
plt.scatter(x_list, slope_list, color = "blue", alpha = 0.8, s= 100)

plt.show()

# %%
def sing(num_bottles):

    counter = 99

    while counter > 0:

        print(counter, 'bottles of beer on the wall,', counter, 'bottles of beer')

        counter = counter - 1

        print('Take one down and pass it around,' , counter, 'bottles of beer on the wall.', '')
    return counter

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $g(x) = x^3 - 4x^2 + 5$

# %%
# Make some data

x_2 = np.linspace(-2,2,1000)

def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %%
# Plot of Derivative

plt.figure(figsize = [15,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 2, 1)
plt.title("Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([0.5,5.5])
plt.xlabel("x", fontsize = 14)
plt.ylabel("g (x)", fontsize = 14)

plt.plot(x_2, g(x_2), color = "skyblue", linewidth = 4)

# Chart 2: DERİVATİVE

plt.subplot(1, 2, 2)
plt.title("Slope of the Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([-6,8])
plt.grid()
plt.xlabel("x", fontsize = 14)
plt.ylabel("df (x)", fontsize = 14)

plt.plot(x_2, dg(x_2), color = "red", linewidth= 5)

plt.show()

# %% [markdown]
# ## Gradient Descent as a Python Function

# %%
def gradient_descent(derivative_func, initial_guess, multiplyer = 0.02, precision = 0.001,
 max_iter = 300):

    new_x = initial_guess

    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplyer * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))


        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.01, 0.00001)
print("Local min occurs at:", local_min)
print("number of steps:", len(list_x))
# Out:
# Local min occurs at: 1.4141668991848309
# number of steps: 69

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func = dg, initial_guess = -0.1)
print("Local min occurs at:", local_min)
print("number of steps:", len(list_x))
# Out:
# Local min occurs at: -1.4120887490901561
# number of steps: 34

# %%
# Plot of Derivative
local_min, list_x, deriv_list = gradient_descent(derivative_func= dg, initial_guess= 0.1)

# Plot function and derivative and ccater plot side by side

plt.figure(figsize = [15,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 2, 1)
plt.title("Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([0.5,5.5])
plt.xlabel("x", fontsize = 14)
plt.ylabel("g (x)", fontsize = 14)

plt.plot(x_2, g(x_2), color = "blue", linewidth = 4, alpha = 0.7)
plt.scatter(list_x, g(np.array(list_x)), color = "red", s = 100, alpha = 0.7)

# Chart 2: DERİVATİVE

plt.subplot(1, 2, 2)
plt.title("Slope of the Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([-6,8])
plt.grid()
plt.xlabel("x", fontsize = 14)
plt.ylabel("df (x)", fontsize = 14)

plt.plot(x_2, dg(x_2), color = "blue", linewidth= 5, alpha = 0.6)
plt.scatter(list_x, deriv_list, color = "red", s = 100, alpha = 0.6)

plt.show()

# %% [markdown]
# # Example 3 - Divergence, Overflow and Python Tuples
# ## $h(x)= x^5 - 2*x^4 +2$

# %%
# Make data
x_3 = np.linspace(start = -2.5, stop= 2.5, num= 100)

def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
# Plot of Derivative
local_min, list_x, deriv_list = gradient_descent(derivative_func= dh, initial_guess= 0.2,
 max_iter= 71)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize = [15,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 2, 1)

plt.xlim([-1.2,2.5])
plt.ylim([-1,4])

plt.title("Cost Function", fontsize = 16)
plt.xlabel("x", fontsize = 14)
plt.ylabel("h (x)", fontsize = 14)

plt.plot(x_3, h(x_3), color = "blue", linewidth = 4, alpha = 0.7)
plt.scatter(list_x, h(np.array(list_x)), color = "red", s = 100, alpha = 0.7)

# Chart 2: DERİVATİVE

plt.subplot(1, 2, 2)

plt.title("Slope of the Cost Function", fontsize = 16)
plt.xlabel("x", fontsize = 14)
plt.ylabel("dh (x)", fontsize = 14)
plt.grid()
plt.xlim([-1,2])
plt.ylim([-4,5])

plt.plot(x_3, dh(x_3), color = "blue", linewidth= 5, alpha = 0.6)
plt.scatter(list_x, deriv_list, color = "red", s = 100, alpha = 0.6)

plt.show()

print("Local min occurs at:", local_min)
print("Cost at this minimum is:", h(local_min))
print("Number of steps is:", (len(list_x)))
# Out:
# Local min occurs at: 0.3971581828347952
# Cost at this minimum is: 1.9601209573279914
# Number of steps is: 72

# %%
import sys
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %% [markdown]
# ## Python Tuples

# %%
# Creating a Tuple- tuple packing
breakfast = "eggs","bacon","strawberry"
unlucky_numbers = 13,4,9,26,17

print("I looooove", breakfast)
print("I looooove", breakfast[0])
print("My hotel has no" + str(unlucky_numbers) + "th floor")
print("My hotel has no " + str(unlucky_numbers[1]) + "th floor")

main, side, green = breakfast
print("main course is: ", main)

data_tuple = gradient_descent(derivative_func=dh, initial_guess= 0.2)
print("Local min is", data_tuple[0])
print("Cost at the last x value is:", h(data_tuple[0]))
print("Number of data is:", len(data_tuple[1]))
# Out:
# I looooove ('eggs', 'bacon', 'strawberry')
# I looooove eggs
# My hotel has no(13, 4, 9, 26, 17)th floor
# My hotel has no 4th floor
# main course is:  eggs
# Local min is 1.5989534547394717
# Cost at the last x value is: -0.6214287992331258
# Number of data is: 117

# %% [markdown]
# # The Learning Rate

# %%
# Calling Gradient Descent func
local_min, list_x, deriv_list = gradient_descent(derivative_func= dg, initial_guess= 1.9,
multiplyer= 0.02, max_iter= 500)

# Plot function and derivative and ccater plot side by side

plt.figure(figsize = [15,6])

# Chart 1: COST FUNCTION

plt.subplot(1, 2, 1)
plt.title("Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([0.5,5.5])
plt.xlabel("x", fontsize = 14)
plt.ylabel("g (x)", fontsize = 14)

plt.plot(x_2, g(x_2), color = "blue", linewidth = 4, alpha = 0.7)
plt.scatter(list_x, g(np.array(list_x)), color = "red", s = 100, alpha = 0.7)

# Chart 2: DERİVATİVE

plt.subplot(1, 2, 2)
plt.title("Slope of the Cost Function", fontsize = 16)

plt.xlim([-2,2])
plt.ylim([-6,8])
plt.grid()
plt.xlabel("x", fontsize = 14)
plt.ylabel("df (x)", fontsize = 14)

plt.plot(x_2, dg(x_2), color = "blue", linewidth= 5, alpha = 0.6)
plt.scatter(list_x, deriv_list, color = "red", s = 100, alpha = 0.6)

plt.show()

print("Number of data is: ", len(list_x))
# Out:
# Number of data is:  14

# %%
# Run gradient descent 3 times

n = 100

low_gamma = gradient_descent(derivative_func= dg, initial_guess= 3, 
multiplyer= 0.0005, precision= 0.0001, max_iter= n)

mid_gamma = gradient_descent(derivative_func= dg, initial_guess= 3, 
multiplyer= 0.001, precision= 0.0001, max_iter= n)

high_gamma = gradient_descent(derivative_func= dg, initial_guess= 3, 
multiplyer= 0.002, precision= 0.0001, max_iter= n)

# Experiment
insane_gamma = gradient_descent(derivative_func= dg, initial_guess= 1.9, 
multiplyer= 0.2, precision= 0.0001, max_iter= n)

# Plotting reduction in cost for each iteration

plt.figure(figsize = [18,9])

# Chart 1: COST FUNCTION

plt.xlim([0,n])
plt.ylim([0,50])

plt.title("Effect of the Learning Rate", fontsize = 16)
plt.xlabel("Number of iterations", fontsize = 14)
plt.ylabel("Cost", fontsize = 14)

# Velues for our charts
# 1) Y axis data: convert the list to numpy arrays
low_values = np.array(low_gamma[1])

# 2) X axis data: create list from 0 to n+1
iteration_list = list(range(0,n+1))

# plotting low learning rate
plt.plot(iteration_list, g(np.array(low_gamma[1])), color = "lightgreen", linewidth = 4, alpha = 0.7)
plt.scatter(iteration_list, g(np.array(low_gamma[1])), color = "red", s = 80, alpha = 0.7)

# plotting mid learning rate
plt.plot(iteration_list, g(np.array(mid_gamma[1])), color = "steelblue", linewidth = 4, alpha = 0.7)
plt.scatter(iteration_list, g(np.array(mid_gamma[1])), color = "red", s = 80, alpha = 0.7)

# plotting high learning rate
plt.plot(iteration_list, g(np.array(high_gamma[1])), color = "hotpink", linewidth = 4, alpha = 0.7)
plt.scatter(iteration_list, g(np.array(high_gamma[1])), color = "red", s = 80, alpha = 0.7)

# plotting high learning rate
plt.plot(iteration_list, g(np.array(insane_gamma[1])), color = "indigo", linewidth = 4, alpha = 0.7)
plt.scatter(iteration_list, g(np.array(insane_gamma[1])), color = "red", s = 80, alpha = 0.7)

plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3d Charts
# ## Minimise $f(x, y) = \frac{1}{3^{-x^2-y^2}+1}$

# %%
def f(x, y):
    r = 3**(-x**2 - y**2)
    return 1/(r+1)

# %%
# Make our x any y data
x_4 = np.linspace(start = -2, stop= 2, num= 200)
y_4 = np.linspace(start = -2, stop= 2, num= 200)

print(" Shape of x array", x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print("Array after meshgrid: ", x_4.shape)
# Out:
#  Shape of x array (200,)
# Array after meshgrid:  (200, 200)

# %%
fig = plt.figure(figsize=[16,12])
ax = fig.gca(projection = "3d")

ax.set_xlabel("X", fontsize= 18)
ax.set_ylabel("y", fontsize= 18)
ax.set_zlabel("f(x, y", fontsize= 18)


ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap= cm.coolwarm_r, alpha= 0.7)

plt.show()

# %% [markdown]
# ## Partial Derivatives & Symbolic Computation
# ## $$\frac{\partial f}{\partial x} = \frac{ 2x\ln(3) \cdot 3^{-x^2 -y^2}}{(3^{-x^2-y^2}+1)^2}$$
# ## $$\frac{\partial f}{\partial y} = \frac{ 2y\ln(3) \cdot 3^{-x^2 -y^2}}{(3^{-x^2-y^2}+1)^2}$$

# %%
a, b = symbols("x,y")
print("Our cost func f(xiy) is:",f(a,b))
print("Partial derivative with respect to x is :")
diff_f = diff(f(a,b),a)
print(diff_f)
print("Value of f(x,y) at x= 1.8 and y= 1",f(a,b).evalf(subs={a:1.8, b:1.0}))
print("Value of d/dx f(x,y) at x= 1.8 and y= 1",diff(f(a,b),a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost func f(xiy) is: 1/(3**(-x**2 - y**2) + 1)
# Partial derivative with respect to x is :
# 2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# Value of f(x,y) at x= 1.8 and y= 1 0.990604794032582
# Value of d/dx f(x,y) at x= 1.8 and y= 1 0.0368089716197505

# %% [markdown]
# ## Batch Gradient Descent with Sympy

# %%
# Setup
multiplyer = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guesses

for n in range(max_iter):
    gradient_x= diff(f(a,b),a).evalf(subs={a:params[0], b:params[1]})
    gradient_y= diff(f(a,b),b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplyer * gradients

# Results
print("Values in gradient array", gradients)
print("Minimum occurs at x value of:", params[0])
print("Minimum occurs at y value of:", params[1])
print("The cost is:", f(params[0],params[1]))
# Out:
# Values in gradient array [2.01013037525579e-11 1.11673909736433e-11]
# Minimum occurs at x value of: 3.45838599885832e-11
# Minimum occurs at y value of: 1.92132555492129e-11
# The cost is: 0.500000000000000

# %%
# Partial derivative functions example 4
def fpx(x,y):
    r= 3**(-x**2 - y**2)
    return 2*x*log(3)*r/(r+1)**2
def fpy(x,y):
    r= 3**(-x**2 - y**2)
    return 2*y*log(3)*r /(r+1)**2

# %%
# Setup
multiplyer = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guesses

for n in range(max_iter):
    gradient_x= fpx(params[0],params[1])
    gradient_y= fpy(params[0],params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplyer * gradients

# Results
print("Values in gradient array", gradients)
print("Minimum occurs at x value of:", params[0])
print("Minimum occurs at y value of:", params[1])
print("The cost is:", f(params[0],params[1]))
# Out:
# Values in gradient array [2.01013038e-11 1.11673910e-11]
# Minimum occurs at x value of: 3.458385998858304e-11
# Minimum occurs at y value of: 1.9213255549212797e-11
# The cost is: 0.5

# %% [markdown]
# ## Graphing 3D Gradient Descent & Adv Numy Arrays

# %%
# Setup
multiplyer = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guesses
values_array = params.reshape(1,2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x= fpx(params[0],params[1])
    gradient_y= fpy(params[0],params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplyer * gradients
    # values_array = np.append(values_array, params.reshape(1,2), axis = 0)
    values_array = np.concatenate((values_array, params.reshape(1,2)), axis = 0)

# Results
print("Values in gradient array", gradients)
print("Minimum occurs at x value of:", params[0])
print("Minimum occurs at y value of:", params[1])
print("The cost is:", f(params[0],params[1]))
# Out:
# (1, 2)
# Values in gradient array [2.01013038e-11 1.11673910e-11]
# Minimum occurs at x value of: 3.458385998858304e-11
# Minimum occurs at y value of: 1.9213255549212797e-11
# The cost is: 0.5

# %%
fig = plt.figure(figsize=[16,12])
ax = fig.gca(projection = "3d")

ax.set_xlabel("X", fontsize= 18)
ax.set_ylabel("y", fontsize= 18)
ax.set_zlabel("f(x, y", fontsize= 18)


ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap= cm.coolwarm_r, alpha= 0.5)
ax.scatter(values_array[:, 0], values_array[:, 1], f(values_array[:, 0], values_array[:, 1]),
s= 50, color="red")

plt.show()

# %%
# advanced numpy array Practice:

kirk = np.array([["captain","guitar"]])
print(kirk.shape)

hs_band = np.array([["black","mc"],["quest","Drum"]])
print(hs_band.shape)

print("hs_band[0]:", hs_band[0])
print("hs_band[0][1]:", hs_band[0][1])
print("hs_band[1][0]:", hs_band[1][0])

the_roots = np.append(arr = hs_band, values = kirk, axis = 0)
# the_roots = np.append(arr = hs_band, values = kirk.reshape(2,1), axis = 1)
print(the_roots)

print("Printing nicknames...", the_roots[:,0])

the_roots = np.append(arr=the_roots, values= [["malik B", "mc"]], axis = 0)
print("Printing band roles...", the_roots[:,1])
# Out:
# (1, 2)
# (2, 2)
# hs_band[0]: ['black' 'mc']
# hs_band[0][1]: mc
# hs_band[1][0]: quest
# [['black' 'mc']
#  ['quest' 'Drum']
#  ['captain' 'guitar']]
# Printing nicknames... ['black' 'quest' 'captain']
# Printing band roles... ['mc' 'Drum' 'guitar' 'mc']

# %% [markdown]
# # Example 5 - Working with Data & a Real Cost Func
# ## Mean Squared Error: a cost func for regr problems
# ### $RSS = \sum_{i = 1}^{n} \big( y^{(i)}-h_\theta x^{(i)}\big)^2  $
# ### $MSE = \frac{1}{n} \sum_ {i = 1}^{n} \big( y^{(i)}-h_\theta x^{(i)}\big)^2  $

# %%
# make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print("shape of x_5 array:", x_5.shape)
print("shape of y_5 array:", y_5.shape)

regr = LinearRegression()
regr.fit(x_5, y_5)

print("Theta 0:", regr.intercept_[0])
print("Theta 1:", regr.coef_[0][0])
# Out:
# shape of x_5 array: (7, 1)
# shape of y_5 array: (7, 1)
# Theta 0: 0.8475351486029536
# Theta 1: 1.2227264637835915

# %%
plt.scatter(x_5, y_5, s= 50)
plt.plot(x_5, regr.predict(x_5), color="orange", linewidth = 3)
plt.ylabel("Y value")
plt.show()

# %%
# y_hat = theta 0 + theta 1 * X
y_hat = regr.intercept_[0] + regr.coef_[0][0] * x_5
print(f"Est values of y_hat are given below \n{y_hat}")
print(f"In comparison, the actual Y values are \n{y_5}")
# Out:
# Est values of y_hat are given below
# [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual Y values are
# [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
def mse(y, y_hat):
    # mse_calc = 1/7 * sum((y-y_hat)**2)
    # mse_calc = (1/y.size) * sum((y-y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis= 0)
    return mse_calc

# %%
print("Manually calculated MSE is:", mse(y_5, y_hat))
print("MSE regression using manual calc is:", mean_squared_error(y_5, y_hat))
print("MSE regression is:", mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is: 0.9479655759794577
# MSE regression is: 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Func
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace( start= -1, stop= 3, num= nr_thetas)
th_1 = np.linspace( start= -1, stop= 3, num= nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loop

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        # print(plot_t0[i][j])
        y_hat= plot_t0[i][j] + plot_t1[i][j]* x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print("Shapeo f plot_t0:", plot_t0.shape)
print("Shapeo f plot_t1:", plot_t1.shape)
print("Shapeo f plot_cost:", plot_cost.shape)
# Out:
# Shapeo f plot_t0: (200, 200)
# Shapeo f plot_t1: (200, 200)
# Shapeo f plot_cost: (200, 200)

# %%
# Nested loop practice
for i in range(3):
    for j in range(3):
        print("slm cnm")
# Out:
# slm cnm
# slm cnm
# slm cnm
# slm cnm
# slm cnm
# slm cnm
# slm cnm
# slm cnm
# slm cnm

# %%
# plotting MSE
fig = plt.figure(figsize=[15,20])
ax= fig.gca(projection= "3d")

ax.set_xlabel("Theta 0", fontsize= 18)
ax.set_ylabel("Theta 1", fontsize= 18)
ax.set_zlabel("Cost - MSE", fontsize= 18)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap= cm.hot)
plt.show()

# %%
print("Min value of plot_cost:", plot_cost.min())
ij_min = np.unravel_index(indices= plot_cost.argmin(), dims= plot_cost.shape)
print("Min occurs at (i,j):", ij_min)
print("Min MSE for theta 0 at plot_t0[111][90]", plot_t0[111][90])
print("min MSE for theta 1 at plot_t1[111][90]", plot_t1[111][90])
# Out:
# Min value of plot_cost: 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for theta 0 at plot_t0[111][90] 0.8090452261306533
# min MSE for theta 1 at plot_t1[111][90] 1.2311557788944723
# <ipython-input-101-81fd730157ca>:2: DeprecationWarning: 'shape' argument should be used instead of 'dims'
#   ij_min = np.unravel_index(indices= plot_cost.argmin(), dims= plot_cost.shape)

# %% [markdown]
# ## Partial Derivatives of MSE wrt $\theta_0$ and $\theta_1$
# ## $\frac{\partial MSE}{\partial \theta_0} = - \frac{2} {n} \sum_{i=1}^{n} \big(y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) $
# ## $\frac{\partial MSE}{\partial \theta_1} = - \frac{2} {n} \sum_{i=1}^{n} \big(y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)  \big( x^{(i)} \big) $

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# X Values, Y Values, array of theta parameters    
def grad(x,y,thetas):
    n = y.size
    t0_slope = (-2/n) * sum(y - thetas[0] - thetas[1] * x)
    t1_slope = (-2/n) * sum((y - thetas[0] - thetas[1] * x) * x)

    # return np.array([t0_slope[0], t1_slope[1]])
    return np.concatenate((t0_slope, t1_slope), axis = 0)

# %%
multiplyer = 0.01
thetas = np.array([2.9, 2.9])

# Colect data points for scatter plot
plot_vals = thetas.reshape(1,2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5) 

for i in range ( 1000):
    thetas = thetas - multiplyer * grad(x_5, y_5, thetas)

    # append new values to our numpy arays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1,2)), axis = 0)
    mse_vals = np.append(arr = mse_vals, values = mse(y_5, thetas[0]+thetas[1]*x_5))


print("Mins occurs at theta 0:", thetas[0])
print("Mins occurs at theta 1:", thetas[1])
print("MSE is:", mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Mins occurs at theta 0: 0.8532230461743415
# Mins occurs at theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# plotting MSE
fig = plt.figure(figsize=[15,20])
ax= fig.gca(projection= "3d")

ax.set_xlabel("Theta 0", fontsize= 18)
ax.set_ylabel("Theta 1", fontsize= 18)
ax.set_zlabel("Cost - MSE", fontsize= 18)

ax.scatter(plot_vals[:,0], plot_vals[:,1], mse_vals, s= 80, color="black" )
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap= cm.rainbow, alpha= 0.35)
plt.show()
